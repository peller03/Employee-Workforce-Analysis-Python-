# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ADMIN\Desktop\TDI_Python\capstodata.csv")

df.head()
# Out:
#   Employee_Id         Full_Name  Gender  Age  Gender.1 Education_Level  \
# 0   EMP000001     Marie Kim DDS  Female   23       NaN        Master's
# 1   EMP000002      Danny Morgan    Male   26       NaN        Master's
# 2   EMP000003  Crystal Robinson  Female   38       NaN      Bachelor's
# 3   EMP000004        Mark Perez    Male   33       NaN      Bachelor's
# 4   EMP000005     Shannon Jones  Female   24       NaN     High School
#
#     Hire_Date   Exit_Date        Department                Job_Role  \
# 0  26/04/2021  13/04/2022  Store Operations                 Cashier
# 1  03/09/2021         NaN  Store Operations         Sales Associate
# 2  25/08/2016         NaN  Store Operations                 Cashier
# 3  10/12/2021         NaN  Store Operations  Senior Sales Associate
# 4  24/02/2018         NaN  Store Operations                 Cashier
#
#           Job_Level Employment_Type  Base_Salary_Annual Store_Location  \
# 0             Entry       Full-time            25745.40      Charlotte
# 1         Associate       Full-time            39408.57       San Jose
# 2             Entry       Full-time            29319.94   Jacksonville
# 3  Senior_Associate       Full-time            43979.88      Las Vegas
# 4             Entry       Full-time            23560.19        Chicago
#
#    Store_Location_Latitude  Store_Location_Longitude Store_Id Manager_Id  \
# 0                  35.2271                  -80.8431   STR058  EMP001131
# 1                  37.3382                 -121.8863   STR137  EMP002456
# 2                  30.3322                  -81.6557   STR008  EMP000529
# 3                  36.1699                 -115.1398   STR063  EMP001305
# 4                  41.8781                  -87.6298   STR109  EMP001823
#
#           Manager_Name  Manager_Status
# 0       Michelle Walls       Executive
# 1       Jennifer Moore       Executive
# 2       Melissa Bishop  Senior Manager
# 3          Tina Walter  Senior Manager
# 4  Nicholas Fitzgerald  Senior Manager

# %%
df.isnull().sum()
# Out:
# Employee_Id                    0
# Full_Name                      0
# Gender                         0
# Age                            0
# Gender.1                    7500
# Education_Level                0
# Hire_Date                      0
# Exit_Date                   6009
# Department                     0
# Job_Role                       0
# Job_Level                      0
# Employment_Type                0
# Base_Salary_Annual             0
# Store_Location                 0
# Store_Location_Latitude        0
# Store_Location_Longitude       0
# Store_Id                       0
# Manager_Id                     0
# Manager_Name                   0
# Manager_Status                 0
# dtype: int64

# %%
#This drop the 'Gendr.1' column with empty value

df.drop(columns=["Gender.1"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee_Id               7500 non-null   object
#  1   Full_Name                 7500 non-null   object
#  2   Gender                    7500 non-null   object
#  3   Age                       7500 non-null   int64
#  4   Education_Level           7500 non-null   object
#  5   Hire_Date                 7500 non-null   object
#  6   Exit_Date                 1491 non-null   object
#  7   Department                7500 non-null   object
#  8   Job_Role                  7500 non-null   object
#  9   Job_Level                 7500 non-null   object
#  10  Employment_Type           7500 non-null   object
#  11  Base_Salary_Annual        7500 non-null   float64
#  12  Store_Location            7500 non-null   object
#  13  Store_Location_Latitude   7500 non-null   float64
#  14  Store_Location_Longitude  7500 non-null   float64
#  15  Store_Id                  7500 non-null   object
#  16  Manager_Id                7500 non-null   object
#  17  Manager_Name              7500 non-null   object
#  18  Manager_Status            7500 non-null   object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 1.1+ MB

# %%
#Adding a new column called 'Status' to know the employee active and inactive.

df["Status"] = np.where(df["Exit_Date"].isna(), "Active", "Inactive")

df.head()
# Out:
#   Employee_Id         Full_Name  Gender  Age  Gender.1 Education_Level  \
# 0   EMP000001     Marie Kim DDS  Female   23       NaN        Master's
# 1   EMP000002      Danny Morgan    Male   26       NaN        Master's
# 2   EMP000003  Crystal Robinson  Female   38       NaN      Bachelor's
# 3   EMP000004        Mark Perez    Male   33       NaN      Bachelor's
# 4   EMP000005     Shannon Jones  Female   24       NaN     High School
#
#     Hire_Date   Exit_Date        Department                Job_Role  ...  \
# 0  26/04/2021  13/04/2022  Store Operations                 Cashier  ...
# 1  03/09/2021         NaN  Store Operations         Sales Associate  ...
# 2  25/08/2016         NaN  Store Operations                 Cashier  ...
# 3  10/12/2021         NaN  Store Operations  Senior Sales Associate  ...
# 4  24/02/2018         NaN  Store Operations                 Cashier  ...
#
#   Employment_Type Base_Salary_Annual  Store_Location Store_Location_Latitude  \
# 0       Full-time           25745.40       Charlotte                 35.2271
# 1       Full-time           39408.57        San Jose                 37.3382
# 2       Full-time           29319.94    Jacksonville                 30.3322
# 3       Full-time           43979.88       Las Vegas                 36.1699
# 4       Full-time           23560.19         Chicago                 41.8781
#
#    Store_Location_Longitude  Store_Id Manager_Id         Manager_Name  \
# 0                  -80.8431    STR058  EMP001131       Michelle Walls
# 1                 -121.8863    STR137  EMP002456       Jennifer Moore
# 2                  -81.6557    STR008  EMP000529       Melissa Bishop
# 3                 -115.1398    STR063  EMP001305          Tina Walter
# 4                  -87.6298    STR109  EMP001823  Nicholas Fitzgerald
#
#    Manager_Status    Status
# 0       Executive  Inactive
# 1       Executive    Active
# 2  Senior Manager    Active
# 3  Senior Manager    Active
# 4  Senior Manager    Active
#
# [5 rows x 21 columns]

# %%
#I have 18 columns but this select only the on to be display

selected_columns = [
    "Employee_Id",
    "Full_Name",
    "Gender",
    "Age",
    "Education_Level",
    "Department",
    "Job_Role",
    "Job_Level",
    "Employment_Type",
    "Store_Location",
    "Base_Salary_Annual",
    "Status"
]

df[selected_columns].head()
# Out:
#   Employee_Id         Full_Name  Gender  Age Education_Level  \
# 0   EMP000001     Marie Kim DDS  Female   23        Master's
# 1   EMP000002      Danny Morgan    Male   26        Master's
# 2   EMP000003  Crystal Robinson  Female   38      Bachelor's
# 3   EMP000004        Mark Perez    Male   33      Bachelor's
# 4   EMP000005     Shannon Jones  Female   24     High School
#
#          Department                Job_Role         Job_Level Employment_Type  \
# 0  Store Operations                 Cashier             Entry       Full-time
# 1  Store Operations         Sales Associate         Associate       Full-time
# 2  Store Operations                 Cashier             Entry       Full-time
# 3  Store Operations  Senior Sales Associate  Senior_Associate       Full-time
# 4  Store Operations                 Cashier             Entry       Full-time
#
#   Store_Location  Base_Salary_Annual    Status
# 0      Charlotte            25745.40  Inactive
# 1       San Jose            39408.57    Active
# 2   Jacksonville            29319.94    Active
# 3      Las Vegas            43979.88    Active
# 4        Chicago            23560.19    Active

# %%
df['Full_Name'].value_counts()
# Out:
# Full_Name
# Jennifer Smith       6
# Jessica Smith        5
# Michael Smith        5
# Michael Jackson      4
# Christopher Smith    4
#                     ..
# Brent Jordan         1
# Richard Aguirre      1
# Timothy Duncan       1
# Michael Lewis        1
# Mark Perez           1
# Name: count, Length: 7107, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5419
# Female    2081
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 30    379
# 34    372
# 31    372
# 21    365
# 33    364
# 28    363
# 27    358
# 35    348
# 32    348
# 22    314
# 25    313
# 37    308
# 29    306
# 26    301
# 36    300
# 23    297
# 38    281
# 24    254
# 39    228
# 40    208
# 43    164
# 41    163
# 42    144
# 44    138
# 45     95
# 46     91
# 47     84
# 48     62
# 49     43
# 50     35
# 51     30
# 52     19
# 53     13
# 54     12
# 55      9
# 56      5
# 57      4
# 58      4
# 59      2
# 64      2
# 63      1
# 60      1
# Name: count, dtype: int64

# %%
df['Education_Level'].value_counts()
# Out:
# Education_Level
# High School     2665
# Bachelor's      2254
# Some College    1473
# Master's         929
# PhD              179
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Store Operations         3000
# Logistics/Warehousing    1500
# Fresh Produce            1125
# Meat/Fish & Bakery        900
# HR                        225
# Finance                   225
# IT                        225
# Marketing                 150
# Customer Service          150
# Name: count, dtype: int64

# %%
df['Employment_Type'].value_counts()
# Out:
# Employment_Type
# Full-time     4897
# Part-time     1853
# Seasonal       605
# Contractor     145
# Name: count, dtype: int64

# %%
df['Job_Level'].value_counts()
# Out:
# Job_Level
# Entry               4000
# Associate           2500
# Senior_Associate     750
# Supervisor           200
# Manager               30
# Senior_Manager        15
# Executive              5
# Name: count, dtype: int64

# %%
df['Store_Location'].value_counts()
# Out:
# Store_Location
# Fort Worth      330
# Nashville       329
# San Jose        325
# Louisville      323
# Seattle         319
# Denver          316
# Los Angeles     314
# Portland        312
# Dallas          309
# Las Vegas       306
# Philadelphia    305
# San Antonio     303
# Phoenix         297
# Boston          297
# Detroit         294
# Jacksonville    293
# Charlotte       293
# Baltimore       289
# Austin          285
# Houston         284
# Columbus        284
# Memphis         282
# New York        279
# San Diego       270
# Chicago         262
# Name: count, dtype: int64

# %%
#Validation of the status of my dataset 
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
# Check missing values in all columns
missing_summary = df.isnull().sum()
print("Missing values per column:")
print(missing_summary)
# Out:
# Missing values per column:
# Employee_Id                    0
# Full_Name                      0
# Gender                         0
# Age                            0
# Education_Level                0
# Hire_Date                      0
# Exit_Date                   6009
# Department                     0
# Job_Role                       0
# Job_Level                      0
# Employment_Type                0
# Base_Salary_Annual             0
# Store_Location                 0
# Store_Location_Latitude        0
# Store_Location_Longitude       0
# Store_Id                       0
# Manager_Id                     0
# Manager_Name                   0
# Manager_Status                 0
# Status                         0
# dtype: int64

# %%
#check data type 

print(df.dtypes)
# Out:
# Employee_Id                  object
# Full_Name                    object
# Gender                       object
# Age                           int64
# Education_Level              object
# Hire_Date                    object
# Exit_Date                    object
# Department                   object
# Job_Role                     object
# Job_Level                    object
# Employment_Type              object
# Base_Salary_Annual          float64
# Store_Location               object
# Store_Location_Latitude     float64
# Store_Location_Longitude    float64
# Store_Id                     object
# Manager_Id                   object
# Manager_Name                 object
# Manager_Status               object
# Status                       object
# dtype: object

# %%
#Changed the data type to a right format

df['Hire_Date'] = pd.to_datetime(df['Hire_Date'], errors='coerce', dayfirst=True)
df['Exit_Date'] = pd.to_datetime(df['Exit_Date'], errors='coerce', dayfirst=True)

print(df.dtypes)
# Out:
# Employee_Id                         object
# Full_Name                           object
# Gender                              object
# Age                                  int64
# Education_Level                     object
# Hire_Date                   datetime64[ns]
# Exit_Date                   datetime64[ns]
# Department                          object
# Job_Role                            object
# Job_Level                           object
# Employment_Type                     object
# Base_Salary_Annual                 float64
# Store_Location                      object
# Store_Location_Latitude            float64
# Store_Location_Longitude           float64
# Store_Id                            object
# Manager_Id                          object
# Manager_Name                        object
# Manager_Status                      object
# Status                              object
# dtype: object

# %%
df.describe()
# Out:
#                Age                   Hire_Date                   Exit_Date  \
# count  7500.000000                        7500                        1491
# mean     32.450000  2019-10-29 00:05:45.600000  2022-08-22 09:05:40.442656
# min      21.000000         2012-01-04 00:00:00         2012-04-30 00:00:00
# 25%      27.000000         2018-12-19 00:00:00         2021-10-27 12:00:00
# 50%      32.000000         2020-06-26 00:00:00         2022-12-12 00:00:00
# 75%      37.000000         2021-05-13 00:00:00         2023-12-17 12:00:00
# max      64.000000         2022-01-01 00:00:00         2024-12-29 00:00:00
# std       7.482319                         NaN                         NaN
#
#        Base_Salary_Annual  Store_Location_Latitude  Store_Location_Longitude
# count         7500.000000              7500.000000               7500.000000
# mean         27253.855732                36.954572                -96.160918
# min           8823.460000                29.424100               -122.678400
# 25%          19899.520000                32.776700               -112.074000
# 50%          27394.165000                36.169900                -95.369800
# 75%          31945.697500                39.961200                -82.998800
# max         177873.610000                47.606200                -71.058900
# std          10217.242704                 4.878566                 16.457037

# %%
"""
 RQ1) What are the demographic and job-level patterns of the workforce (age, gender, education)?
 """

# Age distribution
plt.figure(figsize=(10,4))
sns.histplot(df['Age'].dropna(), bins=20, kde=True, color='skyblue')
plt.title('Distribution of Employee Age')
plt.show()

# Gender count
plt.figure(figsize=(10,4))
sns.countplot(x='Gender', hue='Gender', data=df, palette='Set2', legend=True)
plt.title('Gender Distribution')
plt.show()

# Job level count
plt.figure(figsize=(10,4))
sns.countplot(x='Job_Level', hue='Job_Level', data=df, palette='pastel', legend=True)
plt.title('Job Level Distribution')
plt.show()

# %%
"""
RQ2) What factors (department, job level, employment type) influence employee turnover (active vs inactive)?
"""

# Turnover rate by Department
turnover = df.groupby('Department')['Status'].value_counts().unstack(fill_value=0)
turnover['Turnover_Rate'] = turnover.get('Inactive', 0) / turnover.sum(axis=1)
turnover[['Turnover_Rate']].sort_values('Turnover_Rate', ascending=False).head(10)
# Out:
# Status                 Turnover_Rate
# Department
# HR                          0.222222
# Logistics/Warehousing       0.222000
# Marketing                   0.206667
# Fresh Produce               0.203556
# Store Operations            0.189333
# Meat/Fish & Bakery          0.188889
# Customer Service            0.186667
# Finance                     0.186667
# IT                          0.177778

# %%
# Visualization: Turnover Rate by Department
plt.figure(figsize=(10,5))
turnover_sorted = turnover.sort_values('Turnover_Rate', ascending=False).head(10)
sns.barplot(x=turnover_sorted['Turnover_Rate'], y=turnover_sorted.index, palette='Reds_r' )
plt.title('Top 10 Departments with Highest Turnover Rates')
plt.xlabel('Turnover Rate')
plt.ylabel('Department')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17492\3754446054.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=turnover_sorted['Turnover_Rate'], y=turnover_sorted.index, palette='Reds_r' )

# %%
"""
RQ3) How do salary and tenure vary by department, job level, and employment type?
"""

# Average salary by Job Level
salary_by_level = df.groupby('Job_Level')['Base_Salary_Annual'].mean().sort_index()
salary_by_level.plot(kind='bar', color='purple', title='Average Salary by Job Level')
plt.ylabel('Average Salary')
plt.show()

# %%
# Calculate tenure in years
df['Hire_Date'] = pd.to_datetime(df['Hire_Date'], errors='coerce', dayfirst=True)
df['Exit_Date'] = pd.to_datetime(df['Exit_Date'], errors='coerce', dayfirst=True)
df['Tenure_Years'] = ((df['Exit_Date'].fillna(pd.Timestamp.today()) - df['Hire_Date']).dt.days / 365).round(1)


# Count active vs inactive per location
summary = df.groupby(['Store_Location', 'Status']).size().unstack(fill_value=0)
summary['Total'] = summary.sum(axis=1)
summary['Turnover_Rate'] = summary.get('Inactive', 0) / summary['Total']

# Add average tenure
avg_tenure = df.groupby('Store_Location')['Tenure_Years'].mean()
summary['Avg_Tenure'] = avg_tenure
summary = summary.reset_index().sort_values('Turnover_Rate', ascending=False)

summary.head(10)
# Out:
# Status Store_Location  Active  Inactive  Total  Turnover_Rate  Avg_Tenure
# 9          Fort Worth     242        88    330       0.266667    5.341515
# 7              Denver     240        76    316       0.240506    5.349051
# 3           Charlotte     229        64    293       0.218430    5.259386
# 5            Columbus     222        62    284       0.218310    5.380634
# 0              Austin     224        61    285       0.214035    5.245263
# 6              Dallas     243        66    309       0.213592    5.300324
# 10            Houston     225        59    284       0.207746    5.309859
# 4             Chicago     208        54    262       0.206107    5.367176
# 14         Louisville     257        66    323       0.204334    5.389783
# 17           New York     222        57    279       0.204301    5.412186

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=summary, x='Avg_Tenure', y='Turnover_Rate', hue='Turnover_Rate', palette='coolwarm')
plt.title('Tenure vs Turnover Rate by Location')
plt.xlabel('Average Tenure (Years)')
plt.ylabel('Turnover Rate')
plt.show()

# %%
plt.figure(figsize=(10,5))
dept_salary = df.groupby('Department')['Base_Salary_Annual'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=dept_salary.values, y=dept_salary.index, palette='viridis')
plt.title('Average Salary by Department (Top 10)')
plt.xlabel('Average Annual Salary ($)')
plt.ylabel('Department')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17492\2380850958.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dept_salary.values, y=dept_salary.index, palette='viridis')

# %%
"""
RQ4) How do age, job level, and salary correlate within the organization?
"""
 

 #  Map job levels to numeric values
df["Job_Level_Num"] = df["Job_Level"].map({
    "Entry": 1,
    "Mid": 2,
    "Senior": 3,
    "Manager": 4,
    "Director": 5
})

# clean Base_Salary_Annual (remove $ or commas, if any)
df["Base_Salary_Annual"] = (
    df["Base_Salary_Annual"]
    .replace('[\$,]', '', regex=True)
    .astype(float)
)

#  Now run correlation
corr_cols = ["Age", "Job_Level_Num", "Base_Salary_Annual"]
corr_matrix = df[corr_cols].corr()

#  Visualize
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation: Age, Job Level, and Salary")
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\$'
# <>:18: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17492\3446841055.py:18: SyntaxWarning: invalid escape sequence '\$'
#   .replace('[\$,]', '', regex=True)

# %%
'''
RQ5) How do location and tenure trends influence workforce distribution and retention? 
'''
# Calculate tenure (in years)
df['Tenure'] = (df['Exit_Date'].fillna(pd.Timestamp.today()) - df['Hire_Date']).dt.days / 365

# Group by store/location
tenure_by_location = df.groupby('Store_Location')['Tenure'].mean().sort_values(ascending=False).head(10)

# Visualize
plt.figure(figsize=(10,5))
tenure_by_location.plot(kind='bar', color='teal', edgecolor='black')
plt.title('Average Employee Tenure by Top 10 Store Locations')
plt.ylabel('Average Tenure (Years)')
plt.xlabel('Store Location')
plt.xticks(rotation=45)
plt.show()
